# %%
import pandas
import matplotlib.pyplot as plt
plt.rcParams['svg.fonttype'] = 'none'

# %%
directory = "./thauera-files/ThaueraPaper/"

# %% [markdown]
# ## Aerobic

# %%
CN = pandas.read_csv("{}/CNRatioAerobic.csv".format(directory),header=None)
Data = pandas.read_csv("{}/PolymerPerCarbonAerobic2.csv".format(directory),header=None)
sources = pandas.read_csv("{}/carbonAerobic.txt".format(directory),index_col=0,header=None).index.to_list()

# %%
Data.index = sources
CN.index = sources

# %%
DataAerobic = Data.copy()
CNAerobic = CN.copy()

# %%
colors = ['#e41a1c','#377eb8','#4daf4a','#984ea3','#ff7f00','#ffff33','#a65628']

# %%
for i in CN.index:
    for idx,j in enumerate(CN.columns):
        plt.plot(CN.loc[i,j],Data.loc[i,j],"o",color=colors[idx])
plt.xlabel("C:N")
plt.ylabel("Yield")
plt.savefig("./figures/CN-aerobic.svg",format="SVG")

# %%
CN.boxplot()
# Out:
# <Axes: >

# %%
[i for i in CN[CN<5].dropna(axis=0).index.to_list()]
# Out:
# ['akg_e',
#  'ala__D_e',
#  'ala__L_e',
#  'asn__L_e',
#  'glc__D_e',
#  'glcn_e',
#  'glu__L_e',
#  'glyc_e',
#  'guln__L_e',
#  'his__L_e',
#  'ins_e',
#  'lac__L_e',
#  'leu__L_e',
#  'pro__L_e',
#  'ptrc_e',
#  'pyr_e',
#  'ser__L_e',
#  'succ_e',
#  'thr__L_e',
#  'urcan_e']

# %%
[i for i in CN[((CN>10) & (CN<20)).any(axis=1)].index.to_list()]
# Out:
# ['4abut_e',
#  '4hphac_e',
#  'ac_e',
#  'acon_C_e',
#  'asp__L_e',
#  'balamd_e',
#  'bhb_e',
#  'btd_RR_e',
#  'cit_e',
#  'etha_e',
#  'orn_e',
#  'peamn_e',
#  'phe__L_e',
#  'ppa_e',
#  'uri_e']

# %% [markdown]
# ## Anaerobic

# %%
CN = pandas.read_csv("{}/CNRatioAnaerobic.csv".format(directory),header=None)
Data = pandas.read_csv("{}/PolymerPerCarbonAnaerobic2.csv".format(directory),header=None)
sources = pandas.read_csv("{}/carbonAnaerobic.txt".format(directory),index_col=0,header=None).index.to_list()

# %%
Data.index = sources
CN.index = sources

# %%
DataAnaerobic = Data.copy()
CNAnaerobic = CN.copy()

# %%
colors = ['#e41a1c','#377eb8','#4daf4a','#984ea3','#ff7f00','#ffff33','#a65628']

# %%
for i in CN.index:
    for idx,j in enumerate(CN.columns):
        plt.plot(CN.loc[i,j],Data.loc[i,j],"o",color=colors[idx])
plt.xlabel("C:N")
plt.ylabel("Data")
plt.savefig("./figures/CN-anaerobic.svg",format="SVG")

# %%
CN.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# ## vs

# %%
mets = set(DataAerobic.index) & set(DataAnaerobic.index)

# %%
for i in mets:
    for idx,j in enumerate(DataAerobic.columns):
        plt.plot(DataAerobic.loc[i,j],DataAnaerobic.loc[i,j],"o",color=colors[idx])
plt.plot([0,1],[0,1],linestyle="--",color="black")
plt.xlabel("Aerobic")
plt.ylabel("Anaerobic")
plt.savefig("./figures/Yield-aerobic-vs-anaerobic.svg",format="SVG")

# %%
mets = set(CNAerobic.index) & set(CNAnaerobic.index)

# %%
for i in mets:
    for idx,j in enumerate(CNAerobic.columns):
        plt.plot(CNAerobic.loc[i,j],CNAnaerobic.loc[i,j],"o",color=colors[idx])
# plt.plot([0,1],[0,1],linestyle="--",color="black")
plt.xlabel("Aerobic")
plt.ylabel("Anaerobic")
plt.savefig("./figures/CN-aerobic-vs-anaerobic.svg",format="SVG")

# %%
CNAerobic
# Out:
#                    0          1          2          3          4          5  \
# 4abut_e    13.301204  13.067240  15.405933  22.450919  16.774894  15.892815
# 4hphac_e   10.087017   9.922407  11.687465  16.953048  12.697800  11.952470
# ac_e       12.768190  12.553425  14.978320  21.778995  16.291245  15.243816
# acon_C_e   10.439392  10.256912  11.602742  16.361141  12.802983  12.397005
# akg_e       1.445471   1.448695   1.418320   1.373584   1.406342   1.416007
# ala__D_e    1.445471   1.448695   1.418320   1.373584   1.406342   1.416007
# ala__L_e    0.913684   0.914795   0.904520   0.889067   0.900523   0.903651
# asn__L_e    1.956421   1.961520   1.914882   1.846922   1.897054   1.910990
# asp__L_e    9.210658   9.066736  10.480935  15.068766  11.391523  10.973603
# balamd_e   14.396939  14.139015  16.944159  24.816080  18.519327  17.276025
# bhb_e      13.301204  13.067240  15.405931  22.450918  16.774891  15.892815
# btd_RR_e   13.511857  13.261552  15.430186  21.950739  16.928988  16.117764
# cit_e      13.858219  13.620497  16.092529  23.159805  17.605790  16.622384
# etha_e     12.818465  12.591510  14.822387  21.588312  16.126003  15.310742
# glc__D_e    0.674301   0.674897   0.668164   0.659519   0.666678   0.669163
# glcn_e      2.615823   2.625739   2.548224   2.410263   2.505666   2.525496
# glu__L_e    0.915387   0.916462   0.910302   0.893997   0.904959   0.905762
# glyc_e      2.850301   2.855353   2.816821   2.743721   2.793535   2.802571
# guln__L_e   2.492834   2.499856   2.461899   2.369290   2.425562   2.430582
# his__L_e    1.439199   1.442767   1.413558   1.370821   1.402410   1.411411
# ins_e       2.067078   2.074474   2.018881   1.906996   1.991077   2.002487
# lac__L_e    1.159700   1.161186   1.153026   1.130087   1.144913   1.146127
# leu__L_e    0.931980   0.933378   0.925775   0.902757   0.918367   0.919426
# orn_e       8.461041   8.319903   9.997079  14.554558  10.861851  10.172076
# peamn_e    13.892010  13.656864  15.447582  21.376125  17.044595  16.491026
# phe__L_e   15.394255  15.128151  18.099625  26.359398  19.766837  18.507811
# ppa_e      16.019695  15.703937  18.576461  26.685734  20.284794  19.236892
# pro__L_e    1.171392   1.173288   1.163089   1.137488   1.153145   1.154508
# ptrc_e      4.224166   4.231252   4.183073   4.085722   4.150250   4.160320
# pyr_e       2.045923   2.052833   1.994848   1.897369   1.968185   1.983653
# ser__L_e    1.429380   1.432160   1.413149   1.372706   1.400847   1.404833
# succ_e      3.621739   3.625324   3.787923   3.820757   3.674428   3.563239
# thr__L_e    3.747803   3.744831   3.820711   4.016488   3.889512   3.946340
# thymd_e     4.468892   4.494401   4.293217   3.986768   4.199205   4.260221
# urcan_e     0.938193   0.939867   0.924833   0.902277   0.918751   0.923665
# uri_e      11.363344  11.176449  12.744395  17.727434  13.975858  13.481687
#
#                    6
# 4abut_e    39.242609
# 4hphac_e   39.266257
# ac_e       32.720039
# acon_C_e   39.268385
# akg_e       1.375890
# ala__D_e    1.375890
# ala__L_e    0.886167
# asn__L_e    1.834513
# asp__L_e   39.233403
# balamd_e   19.636480
# bhb_e      39.242609
# btd_RR_e   19.632643
# cit_e      19.028571
# etha_e     26.169086
# glc__D_e    0.664620
# glcn_e      2.293128
# glu__L_e    0.876286
# glyc_e      2.751631
# guln__L_e   2.293152
# his__L_e    1.375789
# ins_e       1.834387
# lac__L_e    1.089268
# leu__L_e    0.886183
# orn_e      19.616299
# peamn_e    26.181407
# phe__L_e   13.089437
# ppa_e      14.272378
# pro__L_e    1.107737
# ptrc_e      4.127361
# pyr_e       1.834472
# ser__L_e    1.329254
# succ_e      3.634008
# thr__L_e    4.023259
# thymd_e     5.213020
# urcan_e     0.917236
# uri_e      26.184676

# %%
from notebooks.save import execute

# %%
date = "2024_05_10"
out,err=execute("jupyter nbconvert --to html 5.CN.ipynb --output-dir=./notebooks/ --output 5.CN-{}".format(date))

# %%
pandas.Series({k:1 for k in CN.columns}).plot.bar(color=colors,figsize=(8,0.5))
plt.savefig("./figures/CN-colorbar.svg",format="SVG")
