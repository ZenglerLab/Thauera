# %%
import pandas
import os

directory = "./thauera-files/ThaueraPaper/"

# %% [markdown]
# ## Aerobic

# %%
folder = "genesPolAerobic/"

# %%
data = {}
for i in os.listdir("{}/{}/".format(directory,folder)):
    if "csv" not in i: continue
    data[i.split(".csv")[0]] = pandas.read_csv(directory+folder+i,header=None)

# %%
DataAerobic = data.copy()

# %%
scores = {}
for i,df in data.items():
    scores[i] = {
        "eps" : df.sum(0).mean(),
        "carbon" : df.sum(1).mean()
    }
scores = pandas.DataFrame.from_dict(scores).T

# %%
STD = {}
for i,df in data.items():
    STD[i] = {
        "eps" : df.std(0).mean(),
        "carbon" : df.std(1).mean()
    }
STD = pandas.DataFrame.from_dict(STD).T

# %%
DataAerobic = data.copy()
ScoresAerobic = scores.copy()

# %%
scores["eps"].plot.hist(figsize=(4,4))
# Out:
# <Axes: ylabel='Frequency'>

# %%
scores["carbon"].plot.hist(figsize=(4,4))
# Out:
# <Axes: ylabel='Frequency'>

# %%
scores.plot.scatter(x="eps",y="carbon")
# Out:
# <Axes: xlabel='eps', ylabel='carbon'>

# %%
scores[(scores==0).any(axis=1)]
# Out:
#                eps  carbon
# TMZ1T_RS08555  0.0     0.0
# TMZ1T_RS04385  0.0     0.0
# TMZ1T_RS03475  0.0     0.0
# TMZ1T_RS03030  0.0     0.0
# TMZ1T_RS16590  0.0     0.0
# TMZ1T_RS17810  0.0     0.0
# TMZ1T_RS14530  0.0     0.0
# TMZ1T_RS17440  0.0     0.0
# TMZ1T_RS10760  0.0     0.0
# TMZ1T_RS15460  0.0     0.0
# TMZ1T_RS14515  0.0     0.0
# TMZ1T_RS17445  0.0     0.0
# TMZ1T_RS04100  0.0     0.0
# TMZ1T_RS03025  0.0     0.0
# TMZ1T_RS03050  0.0     0.0
# TMZ1T_RS14705  0.0     0.0
# TMZ1T_RS08585  0.0     0.0
# TMZ1T_RS08550  0.0     0.0
# TMZ1T_RS16570  0.0     0.0
# TMZ1T_RS13240  0.0     0.0
# TMZ1T_RS17840  0.0     0.0
# TMZ1T_RS08800  0.0     0.0
# TMZ1T_RS03020  0.0     0.0
# TMZ1T_RS05680  0.0     0.0
# TMZ1T_RS05915  0.0     0.0
# TMZ1T_RS04095  0.0     0.0
# TMZ1T_RS07365  0.0     0.0
# TMZ1T_RS16585  0.0     0.0
# TMZ1T_RS16965  0.0     0.0
# TMZ1T_RS16795  0.0     0.0
# TMZ1T_RS08785  0.0     0.0
# TMZ1T_RS11915  0.0     0.0

# %%
STD
# Out:
#                     eps    carbon
# TMZ1T_RS18245  0.000000  0.000000
# TMZ1T_RS03205  0.000000  0.000000
# TMZ1T_RS12185  0.000552  0.000237
# TMZ1T_RS18220  0.000000  0.000000
# TMZ1T_RS06870  0.000000  0.000000
# ...                 ...       ...
# TMZ1T_RS01290  0.000000  0.000000
# TMZ1T_RS13315  0.000000  0.000000
# TMZ1T_RS05585  0.139047  0.009946
# TMZ1T_RS14675  0.171375  0.009946
# TMZ1T_RS12295  0.000657  0.000282
#
# [861 rows x 2 columns]

# %% [markdown]
# ## Anaerobic

# %%
folder = "genesPolAnaerobic/"

# %%
data = {}
for i in os.listdir("{}/{}/".format(directory,folder)):
    if "csv" not in i: continue
    data[i.split(".csv")[0]] = pandas.read_csv(directory+folder+i,header=None)

# %%
scores = {}
for i,df in data.items():
    scores[i] = {
        "eps" : df.sum(0).mean(),
        "carbon" : df.sum(1).mean()
    }
scores = pandas.DataFrame.from_dict(scores).T

# %%
STD = {}
for i,df in data.items():
    STD[i] = {
        "eps" : df.std(0).mean(),
        "carbon" : df.std(1).mean()
    }
STD = pandas.DataFrame.from_dict(STD).T

# %%
DataAnaerobic = data.copy()
ScoresAnaerobic = scores.copy()

# %%
scores["eps"].plot.hist(figsize=(4,4))
# Out:
# <Axes: ylabel='Frequency'>

# %%
scores["carbon"].plot.hist(figsize=(4,4))
# Out:
# <Axes: ylabel='Frequency'>

# %%
scores.plot.scatter(x="eps",y="carbon")
# Out:
# <Axes: xlabel='eps', ylabel='carbon'>

# %%
scores[(scores==0).any(axis=1)]
# Out:
#                eps  carbon
# TMZ1T_RS06900  0.0     0.0
# TMZ1T_RS08555  0.0     0.0
# TMZ1T_RS03475  0.0     0.0
# TMZ1T_RS03030  0.0     0.0
# TMZ1T_RS01005  0.0     0.0
# TMZ1T_RS17810  0.0     0.0
# TMZ1T_RS14530  0.0     0.0
# TMZ1T_RS10760  0.0     0.0
# TMZ1T_RS15460  0.0     0.0
# TMZ1T_RS01010  0.0     0.0
# TMZ1T_RS14515  0.0     0.0
# TMZ1T_RS01000  0.0     0.0
# TMZ1T_RS04100  0.0     0.0
# TMZ1T_RS06890  0.0     0.0
# TMZ1T_RS03025  0.0     0.0
# TMZ1T_RS03050  0.0     0.0
# TMZ1T_RS01020  0.0     0.0
# TMZ1T_RS14705  0.0     0.0
# TMZ1T_RS12770  0.0     0.0
# TMZ1T_RS08550  0.0     0.0
# TMZ1T_RS06895  0.0     0.0
# TMZ1T_RS13240  0.0     0.0
# TMZ1T_RS17840  0.0     0.0
# TMZ1T_RS08800  0.0     0.0
# TMZ1T_RS03020  0.0     0.0
# TMZ1T_RS05680  0.0     0.0
# TMZ1T_RS05915  0.0     0.0
# TMZ1T_RS04095  0.0     0.0
# TMZ1T_RS07365  0.0     0.0
# TMZ1T_RS08510  0.0     0.0
# TMZ1T_RS01015  0.0     0.0
# TMZ1T_RS16965  0.0     0.0
# TMZ1T_RS16795  0.0     0.0
# TMZ1T_RS08785  0.0     0.0
# TMZ1T_RS11915  0.0     0.0

# %%
STD
# Out:
#                     eps    carbon
# TMZ1T_RS18245  0.033643  0.021598
# TMZ1T_RS03205  0.033643  0.021598
# TMZ1T_RS12185  0.033815  0.021675
# TMZ1T_RS18220  0.033643  0.021598
# TMZ1T_RS06870  0.033643  0.021598
# ...                 ...       ...
# TMZ1T_RS01290  0.033643  0.021598
# TMZ1T_RS13315  0.033643  0.021598
# TMZ1T_RS05585  0.178527  0.032397
# TMZ1T_RS14675  0.169031  0.000000
# TMZ1T_RS12295  0.034839  0.023012
#
# [861 rows x 2 columns]

# %% [markdown]
# ## Comparison

# %%
aerobic_lethals = set(ScoresAerobic[ScoresAerobic==0].dropna().index)
anaerobic_lethals = set(ScoresAnaerobic[ScoresAnaerobic==0].dropna().index)

# %%
from matplotlib_venn import venn2

# %%
Lethals = {}
for i in aerobic_lethals|anaerobic_lethals:
    Lethals[i] = {
        "aerobic" : i in aerobic_lethals,
        "anaerobic" : i in anaerobic_lethals
    }
Lethals = pandas.DataFrame.from_dict(Lethals).T

# %%
Lethals[Lethals["aerobic"] != Lethals["anaerobic"]].sort_values("aerobic")
# Out:
#                aerobic  anaerobic
# TMZ1T_RS01005    False       True
# TMZ1T_RS06900    False       True
# TMZ1T_RS01000    False       True
# TMZ1T_RS01015    False       True
# TMZ1T_RS06895    False       True
# TMZ1T_RS08510    False       True
# TMZ1T_RS06890    False       True
# TMZ1T_RS12770    False       True
# TMZ1T_RS01020    False       True
# TMZ1T_RS01010    False       True
# TMZ1T_RS04385     True      False
# TMZ1T_RS16590     True      False
# TMZ1T_RS17440     True      False
# TMZ1T_RS16585     True      False
# TMZ1T_RS16570     True      False
# TMZ1T_RS08585     True      False
# TMZ1T_RS17445     True      False

# %%
Lethals[Lethals["aerobic"] == Lethals["anaerobic"]]
# Out:
#                aerobic  anaerobic
# TMZ1T_RS03030     True       True
# TMZ1T_RS17810     True       True
# TMZ1T_RS05915     True       True
# TMZ1T_RS14705     True       True
# TMZ1T_RS14530     True       True
# TMZ1T_RS05680     True       True
# TMZ1T_RS03050     True       True
# TMZ1T_RS08800     True       True
# TMZ1T_RS03020     True       True
# TMZ1T_RS04100     True       True
# TMZ1T_RS17840     True       True
# TMZ1T_RS15460     True       True
# TMZ1T_RS08550     True       True
# TMZ1T_RS04095     True       True
# TMZ1T_RS03475     True       True
# TMZ1T_RS16795     True       True
# TMZ1T_RS08555     True       True
# TMZ1T_RS07365     True       True
# TMZ1T_RS13240     True       True
# TMZ1T_RS10760     True       True
# TMZ1T_RS08785     True       True
# TMZ1T_RS03025     True       True
# TMZ1T_RS11915     True       True
# TMZ1T_RS16965     True       True
# TMZ1T_RS14515     True       True

# %%
venn2([set(aerobic_lethals),set(anaerobic_lethals)])

# %%
from notebooks.save import execute

# %%
date = "2024_05_10"
out,err=execute("jupyter nbconvert --to html 4.GeneEssentiality.ipynb --output-dir=./notebooks/ --output 4.GeneEssentiality-{}".format(date))
