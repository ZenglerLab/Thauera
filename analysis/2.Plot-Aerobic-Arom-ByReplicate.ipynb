# %%
import pandas
import cobra
import os
from tqdm import tqdm
import numpy
import matplotlib.pyplot as plt
plt.rcParams['svg.fonttype'] = 'none'

directory = "./thauera-files/ThaueraPaper/"

ranks_dir = "ranks-simplified/"

# %% [markdown]
# ## Aerobic

# %%
sampling_dir = "aerobicAromatic/"

# %%
MW = pandas.read_csv(sampling_dir+"MWU-greater-results.csv",index_col=0).drop("Extracellular exchange")

# %%
import seaborn as sns
cmap_df = -numpy.log10(MW)
cmap_df = cmap_df[(cmap_df>=1.3).any(axis=1)] # Only significant
cmap = plt.cm.get_cmap('Reds').copy()
cmap.set_under('white')
vmin,vmax = (1.0,2)
cmap = sns.clustermap(cmap_df,
               row_cluster=True,
               col_cluster=False,
               # vmin=vmin,
               # vmax=vmax,
               annot=True,
               fmt=".1f",
               cmap=cmap,
               # annot_kws={'rotation': 90}
               figsize=(1.0*cmap_df.shape[1],(0.6)*cmap_df.shape[0]),
               # cbar=False,
              )
labels = [i.get_text() for i in cmap.ax_heatmap.yaxis.get_majorticklabels()]
plt.savefig("./figures/aerobic-arom-MWU-greater-results.svg",format="SVG")
# Out:
# /tmp/ipykernel_14229/3802100303.py:4: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap('Reds').copy()

# %%
MW = pandas.read_csv(sampling_dir+"MWU-less-results.csv",index_col=0).drop("Extracellular exchange")

# %%
import seaborn as sns
cmap_df = -numpy.log10(MW)
cmap_df = cmap_df[(cmap_df>=1.3).any(axis=1)] # Only significant
cmap = plt.cm.get_cmap('Blues').copy()
cmap.set_under('white')
vmin,vmax = (1.0,2)
cmap = sns.clustermap(cmap_df,
               row_cluster=True,
               col_cluster=False,
               vmin=vmin,
               vmax=vmax,
               annot=True,
               fmt=".1f",
               cmap=cmap,
               # annot_kws={'rotation': 90}
               figsize=(1.0*cmap_df.shape[1],(0.8)*cmap_df.shape[0]),
               # cbar=False,
              )
labels = [i.get_text() for i in cmap.ax_heatmap.yaxis.get_majorticklabels()]
plt.savefig("./figures/aerobic-arom-MWU-less-results.svg",format="SVG")
# Out:
# /tmp/ipykernel_14229/1878689317.py:4: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap('Blues').copy()

# %% [markdown]
# ## Anaerobic

# %%
sampling_dir = "anaerobicAromatic/"

# %%
MW = pandas.read_csv(sampling_dir+"MWU-greater-results.csv",index_col=0).drop("Extracellular exchange")

# %%
import seaborn as sns
cmap_df = -numpy.log10(MW)
cmap_df = cmap_df[(cmap_df>=1.3).any(axis=1)] # Only significant
cmap = plt.cm.get_cmap('Reds').copy()
cmap.set_under('white')
vmin,vmax = (1.0,2)
cmap = sns.clustermap(cmap_df,
               row_cluster=True,
               col_cluster=False,
               # vmin=vmin,
               # vmax=vmax,
               annot=True,
               fmt=".1f",
               cmap=cmap,
               # annot_kws={'rotation': 90}
               figsize=(1.0*cmap_df.shape[1],(0.6)*cmap_df.shape[0]),
               # cbar=False,
              )
labels = [i.get_text() for i in cmap.ax_heatmap.yaxis.get_majorticklabels()]
plt.savefig("./figures/anaerobic-arom-MWU-greater-results.svg",format="SVG")
# Out:
# /tmp/ipykernel_14229/4067286466.py:4: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap('Reds').copy()

# %%
MW = pandas.read_csv(sampling_dir+"MWU-less-results.csv",index_col=0).drop("Extracellular exchange")

# %%
import seaborn as sns
cmap_df = -numpy.log10(MW)
cmap_df = cmap_df[(cmap_df>=1.3).any(axis=1)] # Only significant
cmap = plt.cm.get_cmap('Blues').copy()
cmap.set_under('white')
vmin,vmax = (1.0,2)
cmap = sns.clustermap(cmap_df,
               row_cluster=True,
               col_cluster=False,
               vmin=vmin,
               vmax=vmax,
               annot=True,
               fmt=".1f",
               cmap=cmap,
               # annot_kws={'rotation': 90}
               figsize=(1.0*cmap_df.shape[1],(0.8)*cmap_df.shape[0]),
               # cbar=False,
              )
labels = [i.get_text() for i in cmap.ax_heatmap.yaxis.get_majorticklabels()]
plt.savefig("./figures/anaerobic-arom-MWU-less-results.svg",format="SVG")
# Out:
# /tmp/ipykernel_14229/3669062279.py:4: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap('Blues').copy()
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 7
#       5 cmap.set_under('white')
#       6 vmin,vmax = (1.0,2)
# ----> 7 cmap = sns.clustermap(cmap_df,
#       8                row_cluster=True,
#       9                col_cluster=False,
#      10                vmin=vmin,
#      11                vmax=vmax,
#      12                annot=True,
#      13                fmt=".1f",
#      14                cmap=cmap,
#      15                # annot_kws={'rotation': 90}
#      16                figsize=(1.0*cmap_df.shape[1],(0.8)*cmap_df.shape[0]),
# ...
