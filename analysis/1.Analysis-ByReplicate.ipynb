# %%
import pandas
import cobra
import os
from tqdm import tqdm


directory = "./thauera-files/ThaueraPaper/"

# sampling_dir = "OptimalHeterotrophic/"
# sampling_dir = "OptimalAnaerobicDesnitrification/"

# sampling_dir = "OptSolarom/"
# sampling_dir = "optimalAromatic/"

# sampling_dir = "aerobicAromatic/"
sampling_dir = "anaerobicAromatic/"

# ranks_dir = "ranks/"
ranks_dir = "ranks-simplified/"

# %%
log_format = '%(asctime)s %(message)s' #%(clientip)-15s %(user)-8s
import logging
from coralme.builder.main import ListHandler
log = logging.getLogger()
logging.basicConfig(filename = "./tmp.log", filemode = 'w', level = logging.WARNING, format = log_format)
logging.captureWarnings(True)

# %% [markdown]
# ### Run

# %%
model = pandas.read_excel(directory + "ModelThauera.xls")
model["Subsystem"].head()
# Out:
# 0    Cofactor and Prosthetic Group Biosynthesis
# 1    Cofactor and Prosthetic Group Biosynthesis
# 2    Cofactor and Prosthetic Group Biosynthesis
# 3    Cofactor and Prosthetic Group Biosynthesis
# 4            Purine and Pyrimidine Biosynthesis
# Name: Subsystem, dtype: object

# %%
Sampling = pandas.DataFrame()
samples = []
for file in os.listdir(directory+sampling_dir):
    if "csv" not in file:
        continue
    met = file.split(".csv")[0]
    df = pandas.read_csv(directory+sampling_dir+file,header=None)

    # Full
    # Sampling[met] = df.stack()

    # Simplified
    Sampling[met] = df.mean(axis=1)
    samples.append(met)

# %%
# Full
# Sampling = pandas.concat([Sampling.reset_index().set_index("level_0"),model["Subsystem"]],axis=1).reset_index()

# %%
# Simplified
Sampling = pandas.concat([Sampling,model["Subsystem"]],axis=1).reset_index()[samples+["Subsystem"]]

# %%
Sampling.to_csv(sampling_dir+"Sampling.csv")

# %%
for col in samples:
    tmp = Sampling[col].sort_values()
    tmp.rank().to_csv(sampling_dir+ranks_dir+"{}_rank.csv".format(col))

# %% [markdown]
# ### Load

# %%
Sampling = pandas.read_csv(sampling_dir+"Sampling.csv",index_col=0)

# %%
samples = [file.split(".csv")[0] for file in os.listdir(directory+sampling_dir) if "csv" in file]

# %%
from scipy.stats import mannwhitneyu
classification = "Subsystem"
def mannwhitney(class_value,col1,col2,alt="greater"):
    Rank = pandas.concat([
        pandas.read_csv(sampling_dir+ranks_dir+"{}_rank.csv".format(col1),index_col=0),
        pandas.read_csv(sampling_dir+ranks_dir+"{}_rank.csv".format(col2),index_col=0),
        Sampling["Subsystem"]
    ],axis=1)
    taxa_df = Rank[Rank[classification] == class_value]
    
    x = taxa_df[col1].values
    y = taxa_df[col2].values
    return mannwhitneyu(x,y, method="exact", alternative=alt)

# %%
ref = "ac_e"
# ref = "glc__D_e"

# alt = "greater"
alt = "less"

# %%
dct = {}
for col in samples:
    if col == ref:
        continue
    dct[col] = {}
    for subs in Sampling["Subsystem"].unique():
        if not isinstance(subs,str) or "Transport" in subs or "Exchange" in subs:
            continue
        ListHandler.print_and_log("Running {}:{}".format(col,subs))
        U1, p = mannwhitney(subs,col,ref,alt=alt)
        dct[col][subs] = p
        ListHandler.print_and_log("Solution: {},{},{}".format(col,subs,p))
# Out:
# Running phenol_e:Cofactor and Prosthetic Group Biosynthesis
# Solution: phenol_e,Cofactor and Prosthetic Group Biosynthesis,0.9999999833661593
# Running phenol_e:Purine and Pyrimidine Biosynthesis
# Solution: phenol_e,Purine and Pyrimidine Biosynthesis,0.9502405057787295
# Running phenol_e:Alternate Carbon Metabolism
# Solution: phenol_e,Alternate Carbon Metabolism,1.0
# Running phenol_e:Tyrosine, Tryptophan, and Phenylalanine Metabolism
# Solution: phenol_e,Tyrosine, Tryptophan, and Phenylalanine Metabolism,0.9775382272605322
# Running phenol_e:Oxidative Phosphorylation
# Solution: phenol_e,Oxidative Phosphorylation,0.9999999958270008
# Running phenol_e:Extracellular exchange
# Solution: phenol_e,Extracellular exchange,0.999999999999841
# Running phenol_e:Valine, Leucine, and Isoleucine Metabolism
# Solution: phenol_e,Valine, Leucine, and Isoleucine Metabolism,0.9077662607288839
# Running phenol_e:Arginine and Proline Metabolism
# Solution: phenol_e,Arginine and Proline Metabolism,0.9732225387163239
# Running phenol_e:Others
# Solution: phenol_e,Others,0.9960067785552267
# Running phenol_e:Membrane Lipid Metabolism
# Solution: phenol_e,Membrane Lipid Metabolism,0.7699139395590854
# Running phenol_e:tRNA Charging
# Solution: phenol_e,tRNA Charging,0.9
# Running phenol_e:Nucleotide Salvage Pathway
# Solution: phenol_e,Nucleotide Salvage Pathway,0.9999936220020624
# Running phenol_e:TCA Cycle
# Solution: phenol_e,TCA Cycle,0.5809700995236262
# Running phenol_e:Pyruvate Metabolism
# Solution: phenol_e,Pyruvate Metabolism,0.7790986790986789
# Running phenol_e:Anaplerotic Reactions
# Solution: phenol_e,Anaplerotic Reactions,0.9175407925407925
# Running phenol_e:Alanine and Aspartate Metabolism
# Solution: phenol_e,Alanine and Aspartate Metabolism,0.937453871963227
# Running phenol_e:Glycolysis/Gluconeogenesis
# Solution: phenol_e,Glycolysis/Gluconeogenesis,0.9915585504025556
# Running phenol_e:Pentose Phosphate Pathway
# Solution: phenol_e,Pentose Phosphate Pathway,0.8111573444727301
# Running phenol_e:Cysteine Metabolism
# Solution: phenol_e,Cysteine Metabolism,0.9999975953715603
# Running phenol_e:Lipopolysaccharide Biosynthesis / Recycling
# Solution: phenol_e,Lipopolysaccharide Biosynthesis / Recycling,0.9999801688041872
# Running phenol_e:Folate Metabolism
# Solution: phenol_e,Folate Metabolism,0.8648371160469901
# Running phenol_e:Cell Envelope Biosynthesis
# Solution: phenol_e,Cell Envelope Biosynthesis,0.999528979038266
# Running phenol_e:Glycine and Serine Metabolism
# Solution: phenol_e,Glycine and Serine Metabolism,0.9922607646697208
# Running phenol_e:Methylglyoxal Metabolism
# Solution: phenol_e,Methylglyoxal Metabolism,0.9999999999999998
# Running phenol_e:Glyoxylate Metabolism
# Solution: phenol_e,Glyoxylate Metabolism,0.9348096348096347
# Running phenol_e:Threonine and Lysine Metabolism
# Solution: phenol_e,Threonine and Lysine Metabolism,0.909939767338494
# Running phenol_e:Methionine Metabolism
# Solution: phenol_e,Methionine Metabolism,0.9989287643466774
# Running phenol_e:Nitrogen Metabolism
# Solution: phenol_e,Nitrogen Metabolism,0.999949272869585
# Running phenol_e:Histidine Metabolism
# Solution: phenol_e,Histidine Metabolism,0.9735353675051484
# Running phenol_e:Glycerophospholipid Metabolism
# Solution: phenol_e,Glycerophospholipid Metabolism,0.9998953949838054
# Running phenol_e:Murein Recycling
# Solution: phenol_e,Murein Recycling,0.9654295170018216
# Running phenol_e:Glutamate Metabolism
# Solution: phenol_e,Glutamate Metabolism,0.9614973262032084
# Running phenol_e:Biomass and maintenance functions
# Solution: phenol_e,Biomass and maintenance functions,0.8285714285714285
# Running phenol_e:Murein Biosynthesis
# Solution: phenol_e,Murein Biosynthesis,0.9315128877769575
# Running phenol_e:Metabolite Repair
# Solution: phenol_e,Metabolite Repair,0.9999999999999997
# Running phenol_e:B-Ketoadipate pathway
# Solution: phenol_e,B-Ketoadipate pathway,0.9999975953715603
# Running phenol_e:Propanoate Metabolism
# Solution: phenol_e,Propanoate Metabolism,0.6666666666666666
# Running phenol_e:Porphyrin and Chlorophyll Metabolism
# Solution: phenol_e,Porphyrin and Chlorophyll Metabolism,0.9990744549568078
# Running phenol_e:Sulfur Metabolism
# Solution: phenol_e,Sulfur Metabolism,0.9
# Running phenol_e:Synthesis and degradation of Ketones Bodies
# Solution: phenol_e,Synthesis and degradation of Ketones Bodies,0.9999999999999999
# Running phenol_e:Pyrimidine Metabolism
# Solution: phenol_e,Pyrimidine Metabolism,1.0
# Running phenol_e:Aromatic compounds metabolism
# Solution: phenol_e,Aromatic compounds metabolism,0.9999999999999999
# Running phenol_e:Glycolate metabolism
# Solution: phenol_e,Glycolate metabolism,1.0
# Running phenol_e:Fatty Acid Metabolism
# Solution: phenol_e,Fatty Acid Metabolism,0.9982407282770721
# Running phenol_e:Phenylacetyl-CoA pathway
# Solution: phenol_e,Phenylacetyl-CoA pathway,1.0
# Running phenol_e:Urea cycle/amino group metabolism
# Solution: phenol_e,Urea cycle/amino group metabolism,0.8
# Running phenol_e:PHAs Metabolism
# Solution: phenol_e,PHAs Metabolism,0.9957568764847817
# Running phenol_e:Ribose Metabolism
# Solution: phenol_e,Ribose Metabolism,1.0
# Running phenol_e:Pantothenate and CoA Biosynthesis
# Solution: phenol_e,Pantothenate and CoA Biosynthesis,0.5
# Running phenol_e:Inositol Metabolism
# Solution: phenol_e,Inositol Metabolism,1.0
# Running phenol_e:Tryptophan metabolism
# Solution: phenol_e,Tryptophan metabolism,1.0
# Running phenol_e:Carbohydrate Metabolism
# Solution: phenol_e,Carbohydrate Metabolism,1.0
# Running phenol_e:PHB Metabolism
# Solution: phenol_e,PHB Metabolism,1.0
# Running pac_e:Cofactor and Prosthetic Group Biosynthesis
# Solution: pac_e,Cofactor and Prosthetic Group Biosynthesis,0.9999999998253603
# Running pac_e:Purine and Pyrimidine Biosynthesis
# Solution: pac_e,Purine and Pyrimidine Biosynthesis,0.9533980390586813
# Running pac_e:Alternate Carbon Metabolism
# Solution: pac_e,Alternate Carbon Metabolism,1.0
# Running pac_e:Tyrosine, Tryptophan, and Phenylalanine Metabolism
# Solution: pac_e,Tyrosine, Tryptophan, and Phenylalanine Metabolism,0.9814227775696273
# Running pac_e:Oxidative Phosphorylation
# Solution: pac_e,Oxidative Phosphorylation,0.99999999558776
# Running pac_e:Extracellular exchange
# Solution: pac_e,Extracellular exchange,0.999999999999841
# Running pac_e:Valine, Leucine, and Isoleucine Metabolism
# Solution: pac_e,Valine, Leucine, and Isoleucine Metabolism,0.8880599861430095
# Running pac_e:Arginine and Proline Metabolism
# Solution: pac_e,Arginine and Proline Metabolism,0.9886028598162412
# Running pac_e:Others
# Solution: pac_e,Others,0.9957568764847817
# Running pac_e:Membrane Lipid Metabolism
# Solution: pac_e,Membrane Lipid Metabolism,0.8581641638443849
# Running pac_e:tRNA Charging
# Solution: pac_e,tRNA Charging,0.9
# Running pac_e:Nucleotide Salvage Pathway
# Solution: pac_e,Nucleotide Salvage Pathway,0.9999811151128524
# Running pac_e:TCA Cycle
# Solution: pac_e,TCA Cycle,0.9634423358912106
# Running pac_e:Pyruvate Metabolism
# Solution: pac_e,Pyruvate Metabolism,0.6395493395493393
# Running pac_e:Anaplerotic Reactions
# Solution: pac_e,Anaplerotic Reactions,0.9358974358974358
# Running pac_e:Alanine and Aspartate Metabolism
# Solution: pac_e,Alanine and Aspartate Metabolism,0.8240550545160855
# Running pac_e:Glycolysis/Gluconeogenesis
# Solution: pac_e,Glycolysis/Gluconeogenesis,0.9879612892695426
# Running pac_e:Pentose Phosphate Pathway
# Solution: pac_e,Pentose Phosphate Pathway,0.7952448009656248
# Running pac_e:Cysteine Metabolism
# Solution: pac_e,Cysteine Metabolism,0.9999975953715603
# Running pac_e:Lipopolysaccharide Biosynthesis / Recycling
# Solution: pac_e,Lipopolysaccharide Biosynthesis / Recycling,0.9999801688041872
# Running pac_e:Folate Metabolism
# Solution: pac_e,Folate Metabolism,0.8728863638356261
# Running pac_e:Cell Envelope Biosynthesis
# Solution: pac_e,Cell Envelope Biosynthesis,0.9999999515850044
# Running pac_e:Glycine and Serine Metabolism
# Solution: pac_e,Glycine and Serine Metabolism,0.9886406360072746
# Running pac_e:Methylglyoxal Metabolism
# Solution: pac_e,Methylglyoxal Metabolism,0.9999999999999998
# Running pac_e:Glyoxylate Metabolism
# Solution: pac_e,Glyoxylate Metabolism,0.9475524475524475
# Running pac_e:Threonine and Lysine Metabolism
# Solution: pac_e,Threonine and Lysine Metabolism,0.9069088796970368
# Running pac_e:Methionine Metabolism
# Solution: pac_e,Methionine Metabolism,0.9984278401085522
# Running pac_e:Nitrogen Metabolism
# Solution: pac_e,Nitrogen Metabolism,0.99996088900854
# Running pac_e:Histidine Metabolism
# Solution: pac_e,Histidine Metabolism,0.9735353675051484
# Running pac_e:Glycerophospholipid Metabolism
# Solution: pac_e,Glycerophospholipid Metabolism,0.9999999996244838
# Running pac_e:Murein Recycling
# Solution: pac_e,Murein Recycling,0.9260317941411687
# Running pac_e:Glutamate Metabolism
# Solution: pac_e,Glutamate Metabolism,0.9432538050185106
# Running pac_e:Biomass and maintenance functions
# Solution: pac_e,Biomass and maintenance functions,0.8285714285714285
# Running pac_e:Murein Biosynthesis
# Solution: pac_e,Murein Biosynthesis,0.9882519266682444
# Running pac_e:Metabolite Repair
# Solution: pac_e,Metabolite Repair,0.9999999999999997
# Running pac_e:B-Ketoadipate pathway
# Solution: pac_e,B-Ketoadipate pathway,0.9999975953715603
# Running pac_e:Propanoate Metabolism
# Solution: pac_e,Propanoate Metabolism,0.6666666666666666
# Running pac_e:Porphyrin and Chlorophyll Metabolism
# Solution: pac_e,Porphyrin and Chlorophyll Metabolism,0.9990744549568078
# Running pac_e:Sulfur Metabolism
# Solution: pac_e,Sulfur Metabolism,0.9
# Running pac_e:Synthesis and degradation of Ketones Bodies
# Solution: pac_e,Synthesis and degradation of Ketones Bodies,0.9999999999999999
# Running pac_e:Pyrimidine Metabolism
# Solution: pac_e,Pyrimidine Metabolism,1.0
# Running pac_e:Aromatic compounds metabolism
# Solution: pac_e,Aromatic compounds metabolism,0.9999999999999999
# Running pac_e:Glycolate metabolism
# Solution: pac_e,Glycolate metabolism,1.0
# Running pac_e:Fatty Acid Metabolism
# Solution: pac_e,Fatty Acid Metabolism,0.9982407282770721
# Running pac_e:Phenylacetyl-CoA pathway
# Solution: pac_e,Phenylacetyl-CoA pathway,1.0
# Running pac_e:Urea cycle/amino group metabolism
# Solution: pac_e,Urea cycle/amino group metabolism,0.65
# Running pac_e:PHAs Metabolism
# Solution: pac_e,PHAs Metabolism,0.9993033107414653
# Running pac_e:Ribose Metabolism
# Solution: pac_e,Ribose Metabolism,0.5
# Running pac_e:Pantothenate and CoA Biosynthesis
# Solution: pac_e,Pantothenate and CoA Biosynthesis,0.5
# Running pac_e:Inositol Metabolism
# Solution: pac_e,Inositol Metabolism,1.0
# Running pac_e:Tryptophan metabolism
# Solution: pac_e,Tryptophan metabolism,1.0
# Running pac_e:Carbohydrate Metabolism
# Solution: pac_e,Carbohydrate Metabolism,1.0
# Running pac_e:PHB Metabolism
# Solution: pac_e,PHB Metabolism,1.0
# Running bz_e:Cofactor and Prosthetic Group Biosynthesis
# Solution: bz_e,Cofactor and Prosthetic Group Biosynthesis,0.9999999961860864
# Running bz_e:Purine and Pyrimidine Biosynthesis
# Solution: bz_e,Purine and Pyrimidine Biosynthesis,0.9533980390586813
# Running bz_e:Alternate Carbon Metabolism
# Solution: bz_e,Alternate Carbon Metabolism,1.0
# Running bz_e:Tyrosine, Tryptophan, and Phenylalanine Metabolism
# Solution: bz_e,Tyrosine, Tryptophan, and Phenylalanine Metabolism,0.9801958840559715
# Running bz_e:Oxidative Phosphorylation
# Solution: bz_e,Oxidative Phosphorylation,0.9999999953354004
# Running bz_e:Extracellular exchange
# Solution: bz_e,Extracellular exchange,0.999999999999841
# Running bz_e:Valine, Leucine, and Isoleucine Metabolism
# Solution: bz_e,Valine, Leucine, and Isoleucine Metabolism,0.892676888616812
# Running bz_e:Arginine and Proline Metabolism
# Solution: bz_e,Arginine and Proline Metabolism,0.9769256004628626
# Running bz_e:Others
# Solution: bz_e,Others,0.9946151191190098
# Running bz_e:Membrane Lipid Metabolism
# Solution: bz_e,Membrane Lipid Metabolism,0.8741839789332249
# Running bz_e:tRNA Charging
# Solution: bz_e,tRNA Charging,0.9
# Running bz_e:Nucleotide Salvage Pathway
# Solution: bz_e,Nucleotide Salvage Pathway,0.9999963420772142
# Running bz_e:TCA Cycle
# Solution: bz_e,TCA Cycle,0.8564558960241575
# Running bz_e:Pyruvate Metabolism
# Solution: bz_e,Pyruvate Metabolism,0.6007770007770006
# Running bz_e:Anaplerotic Reactions
# Solution: bz_e,Anaplerotic Reactions,0.9358974358974358
# Running bz_e:Alanine and Aspartate Metabolism
# Solution: bz_e,Alanine and Aspartate Metabolism,0.9482386593081167
# Running bz_e:Glycolysis/Gluconeogenesis
# Solution: bz_e,Glycolysis/Gluconeogenesis,0.9906401398952179
# Running bz_e:Pentose Phosphate Pathway
# Solution: bz_e,Pentose Phosphate Pathway,0.7952448009656248
# Running bz_e:Cysteine Metabolism
# Solution: bz_e,Cysteine Metabolism,0.9999975953715603
# Running bz_e:Lipopolysaccharide Biosynthesis / Recycling
# Solution: bz_e,Lipopolysaccharide Biosynthesis / Recycling,0.9999801688041872
# Running bz_e:Folate Metabolism
# Solution: bz_e,Folate Metabolism,0.8648371160469901
# Running bz_e:Cell Envelope Biosynthesis
# Solution: bz_e,Cell Envelope Biosynthesis,0.9999999851967037
# Running bz_e:Glycine and Serine Metabolism
# Solution: bz_e,Glycine and Serine Metabolism,0.9877661386584338
# Running bz_e:Methylglyoxal Metabolism
# Solution: bz_e,Methylglyoxal Metabolism,0.9999999999999998
# Running bz_e:Glyoxylate Metabolism
# Solution: bz_e,Glyoxylate Metabolism,0.9348096348096347
# Running bz_e:Threonine and Lysine Metabolism
# Solution: bz_e,Threonine and Lysine Metabolism,0.9430284396367931
# Running bz_e:Methionine Metabolism
# Solution: bz_e,Methionine Metabolism,0.9989871437672637
# Running bz_e:Nitrogen Metabolism
# Solution: bz_e,Nitrogen Metabolism,0.999949272869585
# Running bz_e:Histidine Metabolism
# Solution: bz_e,Histidine Metabolism,0.7627708277191685
# Running bz_e:Glycerophospholipid Metabolism
# Solution: bz_e,Glycerophospholipid Metabolism,0.9999995737118118
# Running bz_e:Murein Recycling
# Solution: bz_e,Murein Recycling,0.006781410106555348
# Running bz_e:Glutamate Metabolism
# Solution: bz_e,Glutamate Metabolism,0.9530440148087205
# Running bz_e:Biomass and maintenance functions
# Solution: bz_e,Biomass and maintenance functions,0.8285714285714285
# Running bz_e:Murein Biosynthesis
# Solution: bz_e,Murein Biosynthesis,0.9662519230580785
# Running bz_e:Metabolite Repair
# Solution: bz_e,Metabolite Repair,0.9999999999999997
# Running bz_e:B-Ketoadipate pathway
# Solution: bz_e,B-Ketoadipate pathway,0.9999975953715603
# Running bz_e:Propanoate Metabolism
# Solution: bz_e,Propanoate Metabolism,0.6666666666666666
# Running bz_e:Porphyrin and Chlorophyll Metabolism
# Solution: bz_e,Porphyrin and Chlorophyll Metabolism,0.9990744549568078
# Running bz_e:Sulfur Metabolism
# Solution: bz_e,Sulfur Metabolism,0.9
# Running bz_e:Synthesis and degradation of Ketones Bodies
# Solution: bz_e,Synthesis and degradation of Ketones Bodies,0.9999999999999999
# Running bz_e:Pyrimidine Metabolism
# Solution: bz_e,Pyrimidine Metabolism,1.0
# Running bz_e:Aromatic compounds metabolism
# Solution: bz_e,Aromatic compounds metabolism,0.9999999999999999
# Running bz_e:Glycolate metabolism
# Solution: bz_e,Glycolate metabolism,1.0
# Running bz_e:Fatty Acid Metabolism
# Solution: bz_e,Fatty Acid Metabolism,0.9894065548924883
# Running bz_e:Phenylacetyl-CoA pathway
# Solution: bz_e,Phenylacetyl-CoA pathway,1.0
# Running bz_e:Urea cycle/amino group metabolism
# Solution: bz_e,Urea cycle/amino group metabolism,0.35
# Running bz_e:PHAs Metabolism
# Solution: bz_e,PHAs Metabolism,0.9952156763043389
# Running bz_e:Ribose Metabolism
# Solution: bz_e,Ribose Metabolism,0.5
# Running bz_e:Pantothenate and CoA Biosynthesis
# Solution: bz_e,Pantothenate and CoA Biosynthesis,0.5
# Running bz_e:Inositol Metabolism
# Solution: bz_e,Inositol Metabolism,1.0
# Running bz_e:Tryptophan metabolism
# Solution: bz_e,Tryptophan metabolism,1.0
# Running bz_e:Carbohydrate Metabolism
# Solution: bz_e,Carbohydrate Metabolism,1.0
# Running bz_e:PHB Metabolism
# Solution: bz_e,PHB Metabolism,1.0
# Running tol_e:Cofactor and Prosthetic Group Biosynthesis
# Solution: tol_e,Cofactor and Prosthetic Group Biosynthesis,0.9999999995070514
# Running tol_e:Purine and Pyrimidine Biosynthesis
# Solution: tol_e,Purine and Pyrimidine Biosynthesis,0.9502405057787295
# Running tol_e:Alternate Carbon Metabolism
# Solution: tol_e,Alternate Carbon Metabolism,1.0
# Running tol_e:Tyrosine, Tryptophan, and Phenylalanine Metabolism
# Solution: tol_e,Tyrosine, Tryptophan, and Phenylalanine Metabolism,0.9836858831197094
# Running tol_e:Oxidative Phosphorylation
# Solution: tol_e,Oxidative Phosphorylation,0.9999999950692363
# Running tol_e:Extracellular exchange
# Solution: tol_e,Extracellular exchange,0.999999999999841
# Running tol_e:Valine, Leucine, and Isoleucine Metabolism
# Solution: tol_e,Valine, Leucine, and Isoleucine Metabolism,0.9077662607288839
# Running tol_e:Arginine and Proline Metabolism
# Solution: tol_e,Arginine and Proline Metabolism,0.9893982544611597
# Running tol_e:Others
# Solution: tol_e,Others,0.9968819440339832
# Running tol_e:Membrane Lipid Metabolism
# Solution: tol_e,Membrane Lipid Metabolism,0.9007567771874271
# Running tol_e:tRNA Charging
# Solution: tol_e,tRNA Charging,0.9
# Running tol_e:Nucleotide Salvage Pathway
# Solution: tol_e,Nucleotide Salvage Pathway,0.9999965217828284
# Running tol_e:TCA Cycle
# Solution: tol_e,TCA Cycle,0.5517334112330632
# Running tol_e:Pyruvate Metabolism
# Solution: tol_e,Pyruvate Metabolism,0.6395493395493393
# Running tol_e:Anaplerotic Reactions
# Solution: tol_e,Anaplerotic Reactions,0.9513403263403263
# Running tol_e:Alanine and Aspartate Metabolism
# Solution: tol_e,Alanine and Aspartate Metabolism,0.8240550545160855
# Running tol_e:Glycolysis/Gluconeogenesis
# Solution: tol_e,Glycolysis/Gluconeogenesis,0.9814894159584197
# Running tol_e:Pentose Phosphate Pathway
# Solution: tol_e,Pentose Phosphate Pathway,0.867165207924395
# Running tol_e:Cysteine Metabolism
# Solution: tol_e,Cysteine Metabolism,0.9999975953715603
# Running tol_e:Lipopolysaccharide Biosynthesis / Recycling
# Solution: tol_e,Lipopolysaccharide Biosynthesis / Recycling,0.9999801688041872
# Running tol_e:Folate Metabolism
# Solution: tol_e,Folate Metabolism,0.8950643390645302
# Running tol_e:Cell Envelope Biosynthesis
# Solution: tol_e,Cell Envelope Biosynthesis,0.9999999966317545
# Running tol_e:Glycine and Serine Metabolism
# Solution: tol_e,Glycine and Serine Metabolism,0.9836783221655294
# Running tol_e:Methylglyoxal Metabolism
# Solution: tol_e,Methylglyoxal Metabolism,0.9999999999999998
# Running tol_e:Glyoxylate Metabolism
# Solution: tol_e,Glyoxylate Metabolism,0.9475524475524475
# Running tol_e:Threonine and Lysine Metabolism
# Solution: tol_e,Threonine and Lysine Metabolism,0.9451194086018841
# Running tol_e:Methionine Metabolism
# Solution: tol_e,Methionine Metabolism,0.9990953802723269
# Running tol_e:Nitrogen Metabolism
# Solution: tol_e,Nitrogen Metabolism,0.999934590668202
# Running tol_e:Histidine Metabolism
# Solution: tol_e,Histidine Metabolism,0.9735353675051484
# Running tol_e:Glycerophospholipid Metabolism
# Solution: tol_e,Glycerophospholipid Metabolism,0.9999999998173623
# Running tol_e:Murein Recycling
# Solution: tol_e,Murein Recycling,0.9789744565148144
# Running tol_e:Glutamate Metabolism
# Solution: tol_e,Glutamate Metabolism,0.9530440148087205
# Running tol_e:Biomass and maintenance functions
# Solution: tol_e,Biomass and maintenance functions,0.8285714285714285
# Running tol_e:Murein Biosynthesis
# Solution: tol_e,Murein Biosynthesis,0.9882519266682444
# Running tol_e:Metabolite Repair
# Solution: tol_e,Metabolite Repair,0.9999999999999997
# Running tol_e:B-Ketoadipate pathway
# Solution: tol_e,B-Ketoadipate pathway,0.9999975953715603
# Running tol_e:Propanoate Metabolism
# Solution: tol_e,Propanoate Metabolism,0.6666666666666666
# Running tol_e:Porphyrin and Chlorophyll Metabolism
# Solution: tol_e,Porphyrin and Chlorophyll Metabolism,0.9990744549568078
# Running tol_e:Sulfur Metabolism
# Solution: tol_e,Sulfur Metabolism,0.9
# Running tol_e:Synthesis and degradation of Ketones Bodies
# Solution: tol_e,Synthesis and degradation of Ketones Bodies,0.9999999999999999
# Running tol_e:Pyrimidine Metabolism
# Solution: tol_e,Pyrimidine Metabolism,1.0
# Running tol_e:Aromatic compounds metabolism
# Solution: tol_e,Aromatic compounds metabolism,0.9999999999999999
# Running tol_e:Glycolate metabolism
# Solution: tol_e,Glycolate metabolism,1.0
# Running tol_e:Fatty Acid Metabolism
# Solution: tol_e,Fatty Acid Metabolism,0.9975472248395924
# Running tol_e:Phenylacetyl-CoA pathway
# Solution: tol_e,Phenylacetyl-CoA pathway,1.0
# Running tol_e:Urea cycle/amino group metabolism
# Solution: tol_e,Urea cycle/amino group metabolism,0.65
# Running tol_e:PHAs Metabolism
# Solution: tol_e,PHAs Metabolism,0.9981412560106676
# Running tol_e:Ribose Metabolism
# Solution: tol_e,Ribose Metabolism,0.5
# Running tol_e:Pantothenate and CoA Biosynthesis
# Solution: tol_e,Pantothenate and CoA Biosynthesis,0.5
# Running tol_e:Inositol Metabolism
# Solution: tol_e,Inositol Metabolism,1.0
# Running tol_e:Tryptophan metabolism
# Solution: tol_e,Tryptophan metabolism,1.0
# Running tol_e:Carbohydrate Metabolism
# Solution: tol_e,Carbohydrate Metabolism,1.0
# Running tol_e:PHB Metabolism
# Solution: tol_e,PHB Metabolism,1.0
# Running 4hbz_e:Cofactor and Prosthetic Group Biosynthesis
# Solution: 4hbz_e,Cofactor and Prosthetic Group Biosynthesis,0.9999999999568211
# Running 4hbz_e:Purine and Pyrimidine Biosynthesis
# Solution: 4hbz_e,Purine and Pyrimidine Biosynthesis,0.9824619113138258
# Running 4hbz_e:Alternate Carbon Metabolism
# Solution: 4hbz_e,Alternate Carbon Metabolism,1.0
# Running 4hbz_e:Tyrosine, Tryptophan, and Phenylalanine Metabolism
# Solution: 4hbz_e,Tyrosine, Tryptophan, and Phenylalanine Metabolism,0.9857117292806642
# Running 4hbz_e:Oxidative Phosphorylation
# Solution: 4hbz_e,Oxidative Phosphorylation,0.9999999953354004
# Running 4hbz_e:Extracellular exchange
# Solution: 4hbz_e,Extracellular exchange,0.999999999999841
# Running 4hbz_e:Valine, Leucine, and Isoleucine Metabolism
# Solution: 4hbz_e,Valine, Leucine, and Isoleucine Metabolism,0.7734443071244894
# Running 4hbz_e:Arginine and Proline Metabolism
# Solution: 4hbz_e,Arginine and Proline Metabolism,0.9891386065819815
# Running 4hbz_e:Others
# Solution: 4hbz_e,Others,0.9957568764847817
# Running 4hbz_e:Membrane Lipid Metabolism
# Solution: 4hbz_e,Membrane Lipid Metabolism,0.9055440106051741
# Running 4hbz_e:tRNA Charging
# Solution: 4hbz_e,tRNA Charging,0.9
# Running 4hbz_e:Nucleotide Salvage Pathway
# Solution: 4hbz_e,Nucleotide Salvage Pathway,0.9999895553087128
# Running 4hbz_e:TCA Cycle
# Solution: 4hbz_e,TCA Cycle,0.6789888886576387
# Running 4hbz_e:Pyruvate Metabolism
# Solution: 4hbz_e,Pyruvate Metabolism,0.6395493395493393
# Running 4hbz_e:Anaplerotic Reactions
# Solution: 4hbz_e,Anaplerotic Reactions,0.9513403263403263
# Running 4hbz_e:Alanine and Aspartate Metabolism
# Solution: 4hbz_e,Alanine and Aspartate Metabolism,0.9430406365444727
# Running 4hbz_e:Glycolysis/Gluconeogenesis
# Solution: 4hbz_e,Glycolysis/Gluconeogenesis,0.9746380366641868
# Running 4hbz_e:Pentose Phosphate Pathway
# Solution: 4hbz_e,Pentose Phosphate Pathway,0.901095942689697
# Running 4hbz_e:Cysteine Metabolism
# Solution: 4hbz_e,Cysteine Metabolism,0.9999975953715603
# Running 4hbz_e:Lipopolysaccharide Biosynthesis / Recycling
# Solution: 4hbz_e,Lipopolysaccharide Biosynthesis / Recycling,0.9999961771783598
# Running 4hbz_e:Folate Metabolism
# Solution: 4hbz_e,Folate Metabolism,0.8879967370088384
# Running 4hbz_e:Cell Envelope Biosynthesis
# Solution: 4hbz_e,Cell Envelope Biosynthesis,0.9999913653484777
# Running 4hbz_e:Glycine and Serine Metabolism
# Solution: 4hbz_e,Glycine and Serine Metabolism,0.9812404124997821
# Running 4hbz_e:Methylglyoxal Metabolism
# Solution: 4hbz_e,Methylglyoxal Metabolism,0.9999999999999998
# Running 4hbz_e:Glyoxylate Metabolism
# Solution: 4hbz_e,Glyoxylate Metabolism,0.9475524475524475
# Running 4hbz_e:Threonine and Lysine Metabolism
# Solution: 4hbz_e,Threonine and Lysine Metabolism,0.9386622927368937
# Running 4hbz_e:Methionine Metabolism
# Solution: 4hbz_e,Methionine Metabolism,0.9991930672974806
# Running 4hbz_e:Nitrogen Metabolism
# Solution: 4hbz_e,Nitrogen Metabolism,0.999934590668202
# Running 4hbz_e:Histidine Metabolism
# Solution: 4hbz_e,Histidine Metabolism,0.9735353675051484
# Running 4hbz_e:Glycerophospholipid Metabolism
# Solution: 4hbz_e,Glycerophospholipid Metabolism,0.9999999996774238
# Running 4hbz_e:Murein Recycling
# Solution: 4hbz_e,Murein Recycling,0.9890927716862321
# Running 4hbz_e:Glutamate Metabolism
# Solution: 4hbz_e,Glutamate Metabolism,0.9530440148087205
# Running 4hbz_e:Biomass and maintenance functions
# Solution: 4hbz_e,Biomass and maintenance functions,0.8285714285714285
# Running 4hbz_e:Murein Biosynthesis
# Solution: 4hbz_e,Murein Biosynthesis,0.9882519266682444
# Running 4hbz_e:Metabolite Repair
# Solution: 4hbz_e,Metabolite Repair,0.9999999999999997
# Running 4hbz_e:B-Ketoadipate pathway
# Solution: 4hbz_e,B-Ketoadipate pathway,0.9999982464907892
# Running 4hbz_e:Propanoate Metabolism
# Solution: 4hbz_e,Propanoate Metabolism,0.6666666666666666
# Running 4hbz_e:Porphyrin and Chlorophyll Metabolism
# Solution: 4hbz_e,Porphyrin and Chlorophyll Metabolism,0.9990744549568078
# Running 4hbz_e:Sulfur Metabolism
# Solution: 4hbz_e,Sulfur Metabolism,0.9
# Running 4hbz_e:Synthesis and degradation of Ketones Bodies
# Solution: 4hbz_e,Synthesis and degradation of Ketones Bodies,0.9999999999999999
# Running 4hbz_e:Pyrimidine Metabolism
# Solution: 4hbz_e,Pyrimidine Metabolism,1.0
# Running 4hbz_e:Aromatic compounds metabolism
# Solution: 4hbz_e,Aromatic compounds metabolism,0.9999999999999999
# Running 4hbz_e:Glycolate metabolism
# Solution: 4hbz_e,Glycolate metabolism,1.0
# Running 4hbz_e:Fatty Acid Metabolism
# Solution: 4hbz_e,Fatty Acid Metabolism,0.9975472248395924
# Running 4hbz_e:Phenylacetyl-CoA pathway
# Solution: 4hbz_e,Phenylacetyl-CoA pathway,1.0
# Running 4hbz_e:Urea cycle/amino group metabolism
# Solution: 4hbz_e,Urea cycle/amino group metabolism,0.65
# Running 4hbz_e:PHAs Metabolism
# Solution: 4hbz_e,PHAs Metabolism,0.9982614128241664
# Running 4hbz_e:Ribose Metabolism
# Solution: 4hbz_e,Ribose Metabolism,0.5
# Running 4hbz_e:Pantothenate and CoA Biosynthesis
# Solution: 4hbz_e,Pantothenate and CoA Biosynthesis,0.5
# Running 4hbz_e:Inositol Metabolism
# Solution: 4hbz_e,Inositol Metabolism,1.0
# Running 4hbz_e:Tryptophan metabolism
# Solution: 4hbz_e,Tryptophan metabolism,1.0
# Running 4hbz_e:Carbohydrate Metabolism
# Solution: 4hbz_e,Carbohydrate Metabolism,1.0
# Running 4hbz_e:PHB Metabolism
# Solution: 4hbz_e,PHB Metabolism,1.0
# Running bzalc_e:Cofactor and Prosthetic Group Biosynthesis
# Solution: bzalc_e,Cofactor and Prosthetic Group Biosynthesis,0.9999999985532165
# Running bzalc_e:Purine and Pyrimidine Biosynthesis
# Solution: bzalc_e,Purine and Pyrimidine Biosynthesis,0.9644772053299038
# Running bzalc_e:Alternate Carbon Metabolism
# Solution: bzalc_e,Alternate Carbon Metabolism,1.0
# Running bzalc_e:Tyrosine, Tryptophan, and Phenylalanine Metabolism
# Solution: bzalc_e,Tyrosine, Tryptophan, and Phenylalanine Metabolism,0.9842138064797397
# Running bzalc_e:Oxidative Phosphorylation
# Solution: bzalc_e,Oxidative Phosphorylation,0.999999994788548
# Running bzalc_e:Extracellular exchange
# Solution: bzalc_e,Extracellular exchange,0.999999999999841
# Running bzalc_e:Valine, Leucine, and Isoleucine Metabolism
# Solution: bzalc_e,Valine, Leucine, and Isoleucine Metabolism,0.9057110044912876
# Running bzalc_e:Arginine and Proline Metabolism
# Solution: bzalc_e,Arginine and Proline Metabolism,0.9891386065819815
# Running bzalc_e:Others
# Solution: bzalc_e,Others,0.9960067785552267
# Running bzalc_e:Membrane Lipid Metabolism
# Solution: bzalc_e,Membrane Lipid Metabolism,0.8941042827099193
# Running bzalc_e:tRNA Charging
# Solution: bzalc_e,tRNA Charging,0.9
# Running bzalc_e:Nucleotide Salvage Pathway
# Solution: bzalc_e,Nucleotide Salvage Pathway,0.999997588547938
# Running bzalc_e:TCA Cycle
# Solution: bzalc_e,TCA Cycle,0.23383681340860246
# Running bzalc_e:Pyruvate Metabolism
# Solution: bzalc_e,Pyruvate Metabolism,0.8088578088578087
# Running bzalc_e:Anaplerotic Reactions
# Solution: bzalc_e,Anaplerotic Reactions,0.9513403263403263
# Running bzalc_e:Alanine and Aspartate Metabolism
# Solution: bzalc_e,Alanine and Aspartate Metabolism,0.9109437738990841
# Running bzalc_e:Glycolysis/Gluconeogenesis
# Solution: bzalc_e,Glycolysis/Gluconeogenesis,0.9906401398952179
# Running bzalc_e:Pentose Phosphate Pathway
# Solution: bzalc_e,Pentose Phosphate Pathway,0.7050621339893112
# Running bzalc_e:Cysteine Metabolism
# Solution: bzalc_e,Cysteine Metabolism,0.9999975953715603
# Running bzalc_e:Lipopolysaccharide Biosynthesis / Recycling
# Solution: bzalc_e,Lipopolysaccharide Biosynthesis / Recycling,0.9999961771783598
# Running bzalc_e:Folate Metabolism
# Solution: bzalc_e,Folate Metabolism,0.8728863638356261
# Running bzalc_e:Cell Envelope Biosynthesis
# Solution: bzalc_e,Cell Envelope Biosynthesis,0.9990219714453686
# Running bzalc_e:Glycine and Serine Metabolism
# Solution: bzalc_e,Glycine and Serine Metabolism,0.9922607646697208
# Running bzalc_e:Methylglyoxal Metabolism
# Solution: bzalc_e,Methylglyoxal Metabolism,0.9999999999999998
# Running bzalc_e:Glyoxylate Metabolism
# Solution: bzalc_e,Glyoxylate Metabolism,0.9475524475524475
# Running bzalc_e:Threonine and Lysine Metabolism
# Solution: bzalc_e,Threonine and Lysine Metabolism,0.9363851211308102
# Running bzalc_e:Methionine Metabolism
# Solution: bzalc_e,Methionine Metabolism,0.9982505094645917
# Running bzalc_e:Nitrogen Metabolism
# Solution: bzalc_e,Nitrogen Metabolism,0.99996088900854
# Running bzalc_e:Histidine Metabolism
# Solution: bzalc_e,Histidine Metabolism,0.7627708277191685
# Running bzalc_e:Glycerophospholipid Metabolism
# Solution: bzalc_e,Glycerophospholipid Metabolism,0.9999991666386918
# Running bzalc_e:Murein Recycling
# Solution: bzalc_e,Murein Recycling,0.005512161436673985
# Running bzalc_e:Glutamate Metabolism
# Solution: bzalc_e,Glutamate Metabolism,0.9530440148087205
# Running bzalc_e:Biomass and maintenance functions
# Solution: bzalc_e,Biomass and maintenance functions,0.8285714285714285
# Running bzalc_e:Murein Biosynthesis
# Solution: bzalc_e,Murein Biosynthesis,0.8752219027225292
# Running bzalc_e:Metabolite Repair
# Solution: bzalc_e,Metabolite Repair,0.9999999999999997
# Running bzalc_e:B-Ketoadipate pathway
# Solution: bzalc_e,B-Ketoadipate pathway,0.9999975953715603
# Running bzalc_e:Propanoate Metabolism
# Solution: bzalc_e,Propanoate Metabolism,0.6666666666666666
# Running bzalc_e:Porphyrin and Chlorophyll Metabolism
# Solution: bzalc_e,Porphyrin and Chlorophyll Metabolism,0.9990744549568078
# Running bzalc_e:Sulfur Metabolism
# Solution: bzalc_e,Sulfur Metabolism,0.9
# Running bzalc_e:Synthesis and degradation of Ketones Bodies
# Solution: bzalc_e,Synthesis and degradation of Ketones Bodies,0.9999999999999999
# Running bzalc_e:Pyrimidine Metabolism
# Solution: bzalc_e,Pyrimidine Metabolism,1.0
# Running bzalc_e:Aromatic compounds metabolism
# Solution: bzalc_e,Aromatic compounds metabolism,0.9999999999999999
# Running bzalc_e:Glycolate metabolism
# Solution: bzalc_e,Glycolate metabolism,1.0
# Running bzalc_e:Fatty Acid Metabolism
# Solution: bzalc_e,Fatty Acid Metabolism,0.9987568487857892
# Running bzalc_e:Phenylacetyl-CoA pathway
# Solution: bzalc_e,Phenylacetyl-CoA pathway,1.0
# Running bzalc_e:Urea cycle/amino group metabolism
# Solution: bzalc_e,Urea cycle/amino group metabolism,0.65
# Running bzalc_e:PHAs Metabolism
# Solution: bzalc_e,PHAs Metabolism,0.9957568764847817
# Running bzalc_e:Ribose Metabolism
# Solution: bzalc_e,Ribose Metabolism,0.5
# Running bzalc_e:Pantothenate and CoA Biosynthesis
# Solution: bzalc_e,Pantothenate and CoA Biosynthesis,0.5
# Running bzalc_e:Inositol Metabolism
# Solution: bzalc_e,Inositol Metabolism,1.0
# Running bzalc_e:Tryptophan metabolism
# Solution: bzalc_e,Tryptophan metabolism,1.0
# Running bzalc_e:Carbohydrate Metabolism
# Solution: bzalc_e,Carbohydrate Metabolism,1.0
# Running bzalc_e:PHB Metabolism
# Solution: bzalc_e,PHB Metabolism,1.0
# Running 4crsol_e:Cofactor and Prosthetic Group Biosynthesis
# Solution: 4crsol_e,Cofactor and Prosthetic Group Biosynthesis,0.9999999736550158
# Running 4crsol_e:Purine and Pyrimidine Biosynthesis
# Solution: 4crsol_e,Purine and Pyrimidine Biosynthesis,0.9502405057787295
# Running 4crsol_e:Alternate Carbon Metabolism
# Solution: 4crsol_e,Alternate Carbon Metabolism,1.0
# Running 4crsol_e:Tyrosine, Tryptophan, and Phenylalanine Metabolism
# Solution: 4crsol_e,Tyrosine, Tryptophan, and Phenylalanine Metabolism,0.9775382272605322
# Running 4crsol_e:Oxidative Phosphorylation
# Solution: 4crsol_e,Oxidative Phosphorylation,0.9999999960537762
# Running 4crsol_e:Extracellular exchange
# Solution: 4crsol_e,Extracellular exchange,0.999999999999841
# Running 4crsol_e:Valine, Leucine, and Isoleucine Metabolism
# Solution: 4crsol_e,Valine, Leucine, and Isoleucine Metabolism,0.9156604830270144
# Running 4crsol_e:Arginine and Proline Metabolism
# Solution: 4crsol_e,Arginine and Proline Metabolism,0.9888735052962455
# Running 4crsol_e:Others
# Solution: 4crsol_e,Others,0.9962436750384245
# Running 4crsol_e:Membrane Lipid Metabolism
# Solution: 4crsol_e,Membrane Lipid Metabolism,0.755631512571392
# Running 4crsol_e:tRNA Charging
# Solution: 4crsol_e,tRNA Charging,0.9
# Running 4crsol_e:Nucleotide Salvage Pathway
# Solution: 4crsol_e,Nucleotide Salvage Pathway,0.9999910407509865
# Running 4crsol_e:TCA Cycle
# Solution: 4crsol_e,TCA Cycle,0.6239762288701517
# Running 4crsol_e:Pyruvate Metabolism
# Solution: 4crsol_e,Pyruvate Metabolism,0.8358974358974357
# Running 4crsol_e:Anaplerotic Reactions
# Solution: 4crsol_e,Anaplerotic Reactions,0.9175407925407925
# Running 4crsol_e:Alanine and Aspartate Metabolism
# Solution: 4crsol_e,Alanine and Aspartate Metabolism,0.9482386593081167
# Running 4crsol_e:Glycolysis/Gluconeogenesis
# Solution: 4crsol_e,Glycolysis/Gluconeogenesis,0.986720216786195
# Running 4crsol_e:Pentose Phosphate Pathway
# Solution: 4crsol_e,Pentose Phosphate Pathway,0.8792381060855957
# Running 4crsol_e:Cysteine Metabolism
# Solution: 4crsol_e,Cysteine Metabolism,0.9999975953715603
# Running 4crsol_e:Lipopolysaccharide Biosynthesis / Recycling
# Solution: 4crsol_e,Lipopolysaccharide Biosynthesis / Recycling,0.9999801688041872
# Running 4crsol_e:Folate Metabolism
# Solution: 4crsol_e,Folate Metabolism,0.8477407922091753
# Running 4crsol_e:Cell Envelope Biosynthesis
# Solution: 4crsol_e,Cell Envelope Biosynthesis,0.9988763956593748
# Running 4crsol_e:Glycine and Serine Metabolism
# Solution: 4crsol_e,Glycine and Serine Metabolism,0.9922607646697208
# Running 4crsol_e:Methylglyoxal Metabolism
# Solution: 4crsol_e,Methylglyoxal Metabolism,0.9999999999999998
# Running 4crsol_e:Glyoxylate Metabolism
# Solution: 4crsol_e,Glyoxylate Metabolism,0.9197358197358196
# Running 4crsol_e:Threonine and Lysine Metabolism
# Solution: 4crsol_e,Threonine and Lysine Metabolism,0.9185995429271941
# Running 4crsol_e:Methionine Metabolism
# Solution: 4crsol_e,Methionine Metabolism,0.9987350048008877
# Running 4crsol_e:Nitrogen Metabolism
# Solution: 4crsol_e,Nitrogen Metabolism,0.9999163438576547
# Running 4crsol_e:Histidine Metabolism
# Solution: 4crsol_e,Histidine Metabolism,0.9735353675051484
# Running 4crsol_e:Glycerophospholipid Metabolism
# Solution: 4crsol_e,Glycerophospholipid Metabolism,0.999994046641738
# Running 4crsol_e:Murein Recycling
# Solution: 4crsol_e,Murein Recycling,0.9665111464997541
# Running 4crsol_e:Glutamate Metabolism
# Solution: 4crsol_e,Glutamate Metabolism,0.9614973262032084
# Running 4crsol_e:Biomass and maintenance functions
# Solution: 4crsol_e,Biomass and maintenance functions,0.8285714285714285
# Running 4crsol_e:Murein Biosynthesis
# Solution: 4crsol_e,Murein Biosynthesis,0.9196572637313951
# Running 4crsol_e:Metabolite Repair
# Solution: 4crsol_e,Metabolite Repair,0.9999999999999997
# Running 4crsol_e:B-Ketoadipate pathway
# Solution: 4crsol_e,B-Ketoadipate pathway,0.9999975953715603
# Running 4crsol_e:Propanoate Metabolism
# Solution: 4crsol_e,Propanoate Metabolism,0.6666666666666666
# Running 4crsol_e:Porphyrin and Chlorophyll Metabolism
# Solution: 4crsol_e,Porphyrin and Chlorophyll Metabolism,0.9990744549568078
# Running 4crsol_e:Sulfur Metabolism
# Solution: 4crsol_e,Sulfur Metabolism,0.9
# Running 4crsol_e:Synthesis and degradation of Ketones Bodies
# Solution: 4crsol_e,Synthesis and degradation of Ketones Bodies,0.9999999999999999
# Running 4crsol_e:Pyrimidine Metabolism
# Solution: 4crsol_e,Pyrimidine Metabolism,1.0
# Running 4crsol_e:Aromatic compounds metabolism
# Solution: 4crsol_e,Aromatic compounds metabolism,0.9999999999999999
# Running 4crsol_e:Glycolate metabolism
# Solution: 4crsol_e,Glycolate metabolism,1.0
# Running 4crsol_e:Fatty Acid Metabolism
# Solution: 4crsol_e,Fatty Acid Metabolism,0.9982407282770721
# Running 4crsol_e:Phenylacetyl-CoA pathway
# Solution: 4crsol_e,Phenylacetyl-CoA pathway,1.0
# Running 4crsol_e:Urea cycle/amino group metabolism
# Solution: 4crsol_e,Urea cycle/amino group metabolism,0.8
# Running 4crsol_e:PHAs Metabolism
# Solution: 4crsol_e,PHAs Metabolism,0.9957568764847817
# Running 4crsol_e:Ribose Metabolism
# Solution: 4crsol_e,Ribose Metabolism,1.0
# Running 4crsol_e:Pantothenate and CoA Biosynthesis
# Solution: 4crsol_e,Pantothenate and CoA Biosynthesis,0.5
# Running 4crsol_e:Inositol Metabolism
# Solution: 4crsol_e,Inositol Metabolism,1.0
# Running 4crsol_e:Tryptophan metabolism
# Solution: 4crsol_e,Tryptophan metabolism,1.0
# Running 4crsol_e:Carbohydrate Metabolism
# Solution: 4crsol_e,Carbohydrate Metabolism,1.0
# Running 4crsol_e:PHB Metabolism
# Solution: 4crsol_e,PHB Metabolism,1.0

# %%
pandas.DataFrame.from_dict(dct).to_csv(sampling_dir+"MWU-{}-results.csv".format(alt))
