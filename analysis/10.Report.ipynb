# %%
import pandas
import cobra
import os
from tqdm import tqdm
import numpy
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['svg.fonttype'] = 'none'

directory = "./thauera-files/ThaueraPaper/report/"

# %% [markdown]
# ## Aerobic

# %%
index = pandas.read_csv(directory+"comAerobic.txt",index_col=0,header=None).index.to_list()
columns = pandas.read_csv(directory+"abundanceMethod.txt",index_col=0,header=None).index.to_list()

# %%
df = pandas.read_csv(directory+"abundanceAerobic.csv",header=None)
df.columns = columns
df.index = index

# %%
cmap_df = df
cmap = plt.cm.get_cmap('YlGnBu').copy()
cmap.set_under('white')
# vmin,vmax = (1.0,2)
cmap = sns.clustermap(cmap_df,
               row_cluster=True,
               col_cluster=False,
               # vmin=vmin,
               # vmax=vmax,
               # annot=True,
               # fmt=".1f",
               cmap=cmap,
               # annot_kws={'rotation': 90}
               # figsize=(1.0*cmap_df.shape[1],(0.6)*cmap_df.shape[0]),
               # cbar=False,
              )
labels = [i.get_text() for i in cmap.ax_heatmap.yaxis.get_majorticklabels()]
plt.savefig("./figures/report-heatmap-aerobic.svg")
# Out:
# /tmp/ipykernel_853838/387848216.py:2: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap('YlGnBu').copy()

# %% [markdown]
# ## Anaerobic

# %%
index = pandas.read_csv(directory+"comAnaerobic.txt",index_col=0,header=None).index.to_list()
columns = pandas.read_csv(directory+"abundanceMethod.txt",index_col=0,header=None).index.to_list()

# %%
df = pandas.read_csv(directory+"abundanceAnaerobic.csv",header=None)
df.columns = columns
df.index = index

# %%
cmap_df = df
cmap = plt.cm.get_cmap('YlGnBu').copy()
cmap.set_under('white')
# vmin,vmax = (1.0,2)
cmap = sns.clustermap(cmap_df,
               row_cluster=True,
               col_cluster=False,
               # vmin=vmin,
               # vmax=vmax,
               # annot=True,
               # fmt=".1f",
               cmap=cmap,
               # annot_kws={'rotation': 90}
               # figsize=(1.0*cmap_df.shape[1],(0.6)*cmap_df.shape[0]),
               # cbar=False,
              )
labels = [i.get_text() for i in cmap.ax_heatmap.yaxis.get_majorticklabels()]
plt.savefig("./figures/report-heatmap-anaerobic.svg")
# Out:
# /tmp/ipykernel_853838/254907008.py:2: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap('YlGnBu').copy()
